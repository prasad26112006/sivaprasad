# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad26112006/sivaprasad/blob/main/pre_processing_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')


text = "The boys are playing football in the playground and enjoyed the game."


words = word_tokenize(text)


stop_words = set(stopwords.words('english'))
filtered_words = [
    word for word in words
    if word.lower() not in stop_words and word.isalpha()
]


stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]


print("Original Text:")
print(text)

print("\nAfter Stop Word Removal:")
print(filtered_words)

print("\nAfter Stemming:")
print(stemmed_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Original Text:
# The boys are playing football in the playground and enjoyed the game.
#
# After Stop Word Removal:
# ['boys', 'playing', 'football', 'playground', 'enjoyed', 'game']
#
# After Stemming:
# ['boy', 'play', 'footbal', 'playground', 'enjoy', 'game']
